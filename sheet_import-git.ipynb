# %% [markdown]
# # This notebook documents my work:
#
#     * Pulling data from a Google Sheet using its API.
#     * Using pandas for data wrangling and manipulation.
#     * Using SQLAlchemy and Pandas to_sql function to upload the data to a database.

# %% [markdown]
# ## Start by importing the libraries

# %%
from __future__ import print_function
import pickle
import os.path
import pandas as pd
import re

#Google libraries
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request

# %% [markdown]
# ## * The google sheet in question can be viewed here:
#     https://docs.google.com/spreadsheets/d/1mIYWBp9ExxlSaKnv22rio9nUzyJvrozYbWCrQdsOVRI/edit?usp=sharing
#
# ## * The SPREADSHEET_ID can be found here:
#     * https://docs.google.com/spreadsheets/d/YOUR_SPREADSHEET_ID/edit#gid=0
#     * Hence, our spreadsheet id is: 1mIYWBp9ExxlSaKnv22rio9nUzyJvrozYbWCrQdsOVRI
#
# ## * The Range name is the name of the sheet in the google sheet you want to use.

# %%
SCOPES = ['https://www.googleapis.com/auth/spreadsheets.readonly']

SPREADSHEET_ID = '1mIYWBp9ExxlSaKnv22rio9nUzyJvrozYbWCrQdsOVRI'
RANGE_NAME  = 'Books'

# %% [markdown]
# ## This function will import all the data from the google sheet in question and get rid of the empty cells. We will then store this data in the sheet variable shown in the next cell

# %%
def get_sheet(SCOPES, SPREADSHEET_ID, RANGE_NAME):
    
    creds = None
    # The file token.pickle stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first
    # time.
    if os.path.exists('token.pickle'):
        with open('token.pickle', 'rb') as token:
            creds = pickle.load(token)
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file('credentials.json', SCOPES)
            creds = flow.run_local_server(port=8910)
        # Save the credentials for the next run
        with open('token.pickle', 'wb') as token:
            pickle.dump(creds, token)

    service = build('sheets', 'v4', credentials=creds)
    
    sheet = service.spreadsheets()
    result = sheet.values().get(spreadsheetId=SPREADSHEET_ID,range=RANGE_NAME).execute()
    values = result.get('values', [])
    
    return values

# %%
sheet = get_sheet(SCOPES, SPREADSHEET_ID, RANGE_NAME)

# %% [markdown]
# ## Import this sheet into a pandas data frame. Since this is going to vary for each sheet, I am not creating a function for this.
#
#
# ## I am doing some basic pandas housekeeping before I go ahead. I am basically dropping some unnecessary columns, renaming others...stuff like that.

# %%
data_df = pd.DataFrame(sheet).dropna()
data_df.reset_index()
data_df.columns = data_df.iloc[0]
data_df = data_df.iloc[1:]
data_df = data_df.drop([''], axis = 1)
data_df.columns = ['start_date', 'date', 'book_title', 'author', 'genre',
       'comments']
data_df = data_df.drop('start_date', axis = 1)

# %%
data_df.head(20)
# Out:
#           date                                         book_title  \
# 5   01/07/2017                                   She Comes First
# 6   01/17/2017        The Sixth Extinctinon: An unnatural history
# 7   01/21/2017                              The Princess Diarist
# 8   01/28/2017                                    Jesus>Religion
# 9   02/03/2017               The Hitchhiker's guide to the Galaxy
# 10  02/12/2017  Chasing the Scream: The first and last days of...
# 11   0218/2017          The Restaurant at the end of the Universe
# 12  02/22/2017                                       Animal Farm
# 13  03/12/2017                                 The Case for Mars
# 14  03/19/2017                          Only the longest threads
# 15  03/30/2017                                            Energy
# 16  04/04/2017                          A Thousand pieces of you
# 17  04/11/2017                     Requiem for the American Dream
# 18  04/21/2017  Listen, Liberal. Or Whatever Happened to the p...
# 19  04/30/2017                                 Star Wars: Thrawn
# 20  05/11/2017                                   Magic of Reality
# 21  05/16/2017                          The wisdom of Insecurity
# 22  05/27/2017    Founding Brothers: The Revolutionary generation
# 23  06/01/2017                  Life, the Universe and Everything
# 24  06/18/2017                              How Jesus Became God
#
#                    author                                             genre  \
# 5             Ian Kerner                                    Human Sexuality
# 6       Elizabeth Kolbert  Anthropology, Science, Archeology, Paleontology
# 7          Carrie Fisher                                            Memoir
# 8       Jefferson Bethke                              Religion/Spirituality
# 9           Douglas Adams                                   Science Fiction
# 10           Johann Hari                  History/ Investigative Journalism
# 11          Douglas Adams                                   Science Fiction
# 12         Goerge Orwell                                           Fiction
# 13         Robert Zubrin                           Science/space exploratio
# 14  Tasneem Zehra Hussain           Popular Science/Science History/Fiction
# 15           Vaclav Smil                                             Energy
# 16          Claudia Gray                                         Fiction/YA
# 17           Naom Chomsky                           History/Current Affairs
# 18          Thomas Frank                                History/ Commentary
# 19          Timothy Zahn                                    Star Wars Canon
# 20        Richard Dawkins                                          Science
# 21             Alan Watts                              Philosophy/self-help
# 22        Joseph J. Ellis                                          History
# 23          Douglas Adams                            Science Fiction/Comedy
# 24        Bart D. Ehrman                                Historical exegeis
#
#                                              comments
# 5      A deeply informative at the art of cunnilingus
# 6   A look at what has caused the five traceable m...
# 7   Carrie Fisher's last book based on her redisco...
# 8   A contemporary opine about the relationship Je...
# 9                Sci-Fi, epic British humor, classic.
# 10  A detailed look on the history of drug war, th...
# 11  The continuing adventures of Arthur, Zaphod, F...
# 12                     Eric Blair being George Orwell
# 13  Jesus H. Christ, there is too much information...
# 14  A deep dive into the some of the most importan...
# 15  Filled with some highly useful information abo...
# 16  Claudia Gray is an increadibly gifted writer. ...
# 17  First Chomsky book, the guy drops some truth o...
# 18  A very concise and compelling history of the D...
# 19  I knew of Thrawn as a character in the periphe...
# 20  The first Dawkins book that i have read. I dia...
# 21  First Alan Watts. Very thought provoking. Also...
# 22  A very interesting, concise yet detailed look ...
# 23  The third book in the hitchiker's trilogy. Dou...
# 24  This book is a deep dive into the historical a...

# %% [markdown]
# ## The genre section of this dataframe has two different delimiters '/' and ','. I am going to unify them and store them in a new column called genre_sep and drop the old genre column.

# %%
data_df['genre_sep'] = data_df['genre'].str.replace(re.escape('/'), ',')

# %%
data_df = data_df.drop('genre', axis = 1)

# %%
data_df
# Out:
#           date                                         book_title  \
# 5   01/07/2017                                   She Comes First
# 6   01/17/2017        The Sixth Extinctinon: An unnatural history
# 7   01/21/2017                              The Princess Diarist
# 8   01/28/2017                                    Jesus>Religion
# 9   02/03/2017               The Hitchhiker's guide to the Galaxy
# 10  02/12/2017  Chasing the Scream: The first and last days of...
# 11   0218/2017          The Restaurant at the end of the Universe
# 12  02/22/2017                                       Animal Farm
# 13  03/12/2017                                 The Case for Mars
# 14  03/19/2017                          Only the longest threads
# 15  03/30/2017                                            Energy
# 16  04/04/2017                          A Thousand pieces of you
# 17  04/11/2017                     Requiem for the American Dream
# 18  04/21/2017  Listen, Liberal. Or Whatever Happened to the p...
# 19  04/30/2017                                 Star Wars: Thrawn
# 20  05/11/2017                                   Magic of Reality
# 21  05/16/2017                          The wisdom of Insecurity
# 22  05/27/2017    Founding Brothers: The Revolutionary generation
# 23  06/01/2017                  Life, the Universe and Everything
# 24  06/18/2017                              How Jesus Became God
# 25  07/01/2017                                  Star Wars: Tarkin
# 26    08/10/17                                                IT
# 27  08/19/2017        CLIMATE CHANGE: What everyone needs to know
# 28  08/30/2017         Austerity: The history of a dangerous idea
# 29    09/06/17                 Astrophysiscs for people in Hurry
# 30     09/2017                       Murder on the Orient Express
# 31  09/22/2017                        Leia: Princess of Alderaan
# 32  10/12/2017                          On the Origin of Species
# 33       10/28                           The body in the library
# 34       11/17                                   Lincoln Unbound
# 35       11/29                                           Artemis
# 36  12/27/2017  The Demon Haunted World: Science as a candle i...
# 37    01/01/18         The Narrative of Life of Fredrick Douglass
#
#                    author                                           comments  \
# 5             Ian Kerner      A deeply informative at the art of cunnilingus
# 6       Elizabeth Kolbert  A look at what has caused the five traceable m...
# 7          Carrie Fisher   Carrie Fisher's last book based on her redisco...
# 8       Jefferson Bethke   A contemporary opine about the relationship Je...
# 9           Douglas Adams               Sci-Fi, epic British humor, classic.
# 10           Johann Hari   A detailed look on the history of drug war, th...
# 11          Douglas Adams  The continuing adventures of Arthur, Zaphod, F...
# 12         Goerge Orwell                      Eric Blair being George Orwell
# 13         Robert Zubrin   Jesus H. Christ, there is too much information...
# 14  Tasneem Zehra Hussain  A deep dive into the some of the most importan...
# 15           Vaclav Smil   Filled with some highly useful information abo...
# 16          Claudia Gray   Claudia Gray is an increadibly gifted writer. ...
# 17           Naom Chomsky  First Chomsky book, the guy drops some truth o...
# 18          Thomas Frank   A very concise and compelling history of the D...
# 19          Timothy Zahn   I knew of Thrawn as a character in the periphe...
# 20        Richard Dawkins  The first Dawkins book that i have read. I dia...
# 21             Alan Watts  First Alan Watts. Very thought provoking. Also...
# 22        Joseph J. Ellis  A very interesting, concise yet detailed look ...
# 23          Douglas Adams  The third book in the hitchiker's trilogy. Dou...
# 24        Bart D. Ehrman   This book is a deep dive into the historical a...
# 25           James Luceno  This is a very  middle of the road Star Wars b...
# 26          Stephen King   This is the answer to the question: What is yo...
# 27            Joseph Romm  Have been meaning to read more about climate c...
# 28            Mark Blyth   This book is ladden with some heacy concepts r...
# 29    Neil deGrasse Tyson  An intro to the wonderous world of astrophysic...
# 30       Agatha Christie   This was my first Agatha Christie mystery. It ...
# 31          Claudia Gray   Claudia Gray creates yet another Star Wars cha...
# 32        Charles Darwin   Yes, this is one of the most defining pieces o...
# 33       Agatha Christie   Okay, so i have read two Agatha Christie books...
# 34            Rich Lowry   This is the first book I am reading about Linc...
# 35             Andy Weir   Well written sci-fi, heist, action book. Has r...
# 36            Carl Sagan   I have been a lifelong Saganist. Carl Sagan's ...
# 37      Fredrick Douglass  Fredrick F*ing Douglass, ladies and gentlemen!...
#
#                                            genre_sep
# 5                                    Human Sexuality
# 6   Anthropology, Science, Archeology, Paleontology
# 7                                            Memoir
# 8                              Religion,Spirituality
# 9                                    Science Fiction
# 10                 History, Investigative Journalism
# 11                                   Science Fiction
# 12                                          Fiction
# 13                          Science,space exploratio
# 14           Popular Science,Science History,Fiction
# 15                                            Energy
# 16                                        Fiction,YA
# 17                           History,Current Affairs
# 18                               History, Commentary
# 19                                   Star Wars Canon
# 20                                          Science
# 21                              Philosophy,self-help
# 22                                          History
# 23                            Science Fiction,Comedy
# 24                               Historical exegeis
# 25                                   Star Wars Canon
# 26                                            Horror
# 27                                          Science
# 28                                        Economics
# 29                                 Science Education
# 30                                           Fiction
# 31                                   Star Wars Canon
# 32                               Science lieterature
# 33                                          Mystery
# 34                                          History
# 35                                            Sci-fi
# 36                                Science Education
# 37                                    History,Memoir

# %% [markdown]
# ## I am going to reorganize the column order to match the schema of the database I created.

# %%
dat_org = data_df[['book_title', 'author', 'genre_sep', 'comments', 'date' ]]

# %%
dat_org
# Out:
#                                            book_title                 author  \
# 5                                    She Comes First             Ian Kerner
# 6         The Sixth Extinctinon: An unnatural history      Elizabeth Kolbert
# 7                               The Princess Diarist          Carrie Fisher
# 8                                     Jesus>Religion       Jefferson Bethke
# 9                The Hitchhiker's guide to the Galaxy          Douglas Adams
# 10  Chasing the Scream: The first and last days of...           Johann Hari
# 11          The Restaurant at the end of the Universe          Douglas Adams
# 12                                       Animal Farm          Goerge Orwell
# 13                                 The Case for Mars          Robert Zubrin
# 14                          Only the longest threads   Tasneem Zehra Hussain
# 15                                            Energy            Vaclav Smil
# 16                          A Thousand pieces of you           Claudia Gray
# 17                     Requiem for the American Dream           Naom Chomsky
# 18  Listen, Liberal. Or Whatever Happened to the p...          Thomas Frank
# 19                                 Star Wars: Thrawn           Timothy Zahn
# 20                                   Magic of Reality        Richard Dawkins
# 21                          The wisdom of Insecurity              Alan Watts
# 22    Founding Brothers: The Revolutionary generation        Joseph J. Ellis
# 23                  Life, the Universe and Everything          Douglas Adams
# 24                              How Jesus Became God         Bart D. Ehrman
# 25                                  Star Wars: Tarkin           James Luceno
# 26                                                IT           Stephen King
# 27        CLIMATE CHANGE: What everyone needs to know            Joseph Romm
# 28         Austerity: The history of a dangerous idea            Mark Blyth
# 29                 Astrophysiscs for people in Hurry     Neil deGrasse Tyson
# 30                       Murder on the Orient Express       Agatha Christie
# 31                        Leia: Princess of Alderaan           Claudia Gray
# 32                          On the Origin of Species         Charles Darwin
# 33                           The body in the library        Agatha Christie
# 34                                   Lincoln Unbound             Rich Lowry
# 35                                           Artemis              Andy Weir
# 36  The Demon Haunted World: Science as a candle i...            Carl Sagan
# 37         The Narrative of Life of Fredrick Douglass      Fredrick Douglass
#
#                                            genre_sep  \
# 5                                    Human Sexuality
# 6   Anthropology, Science, Archeology, Paleontology
# 7                                            Memoir
# 8                              Religion,Spirituality
# 9                                    Science Fiction
# 10                 History, Investigative Journalism
# 11                                   Science Fiction
# 12                                          Fiction
# 13                          Science,space exploratio
# 14           Popular Science,Science History,Fiction
# 15                                            Energy
# 16                                        Fiction,YA
# 17                           History,Current Affairs
# 18                               History, Commentary
# 19                                   Star Wars Canon
# 20                                          Science
# 21                              Philosophy,self-help
# 22                                          History
# 23                            Science Fiction,Comedy
# 24                               Historical exegeis
# 25                                   Star Wars Canon
# 26                                            Horror
# 27                                          Science
# 28                                        Economics
# 29                                 Science Education
# 30                                           Fiction
# 31                                   Star Wars Canon
# 32                               Science lieterature
# 33                                          Mystery
# 34                                          History
# 35                                            Sci-fi
# 36                                Science Education
# 37                                    History,Memoir
#
#                                              comments        date
# 5      A deeply informative at the art of cunnilingus  01/07/2017
# 6   A look at what has caused the five traceable m...  01/17/2017
# 7   Carrie Fisher's last book based on her redisco...  01/21/2017
# 8   A contemporary opine about the relationship Je...  01/28/2017
# 9                Sci-Fi, epic British humor, classic.  02/03/2017
# 10  A detailed look on the history of drug war, th...  02/12/2017
# 11  The continuing adventures of Arthur, Zaphod, F...   0218/2017
# 12                     Eric Blair being George Orwell  02/22/2017
# 13  Jesus H. Christ, there is too much information...  03/12/2017
# 14  A deep dive into the some of the most importan...  03/19/2017
# 15  Filled with some highly useful information abo...  03/30/2017
# 16  Claudia Gray is an increadibly gifted writer. ...  04/04/2017
# 17  First Chomsky book, the guy drops some truth o...  04/11/2017
# 18  A very concise and compelling history of the D...  04/21/2017
# 19  I knew of Thrawn as a character in the periphe...  04/30/2017
# 20  The first Dawkins book that i have read. I dia...  05/11/2017
# 21  First Alan Watts. Very thought provoking. Also...  05/16/2017
# 22  A very interesting, concise yet detailed look ...  05/27/2017
# 23  The third book in the hitchiker's trilogy. Dou...  06/01/2017
# 24  This book is a deep dive into the historical a...  06/18/2017
# 25  This is a very  middle of the road Star Wars b...  07/01/2017
# 26  This is the answer to the question: What is yo...    08/10/17
# 27  Have been meaning to read more about climate c...  08/19/2017
# 28  This book is ladden with some heacy concepts r...  08/30/2017
# 29  An intro to the wonderous world of astrophysic...    09/06/17
# 30  This was my first Agatha Christie mystery. It ...     09/2017
# 31  Claudia Gray creates yet another Star Wars cha...  09/22/2017
# 32  Yes, this is one of the most defining pieces o...  10/12/2017
# 33  Okay, so i have read two Agatha Christie books...       10/28
# 34  This is the first book I am reading about Linc...       11/17
# 35  Well written sci-fi, heist, action book. Has r...       11/29
# 36  I have been a lifelong Saganist. Carl Sagan's ...  12/27/2017
# 37  Fredrick F*ing Douglass, ladies and gentlemen!...    01/01/18

# %% [markdown]
# ## Let's set up the connection to the database now. I will create a dummy database just to make sure that it is working fine.
#
# ##  I will use MYSQL and SQLAlchemy to do this.

# %%
from pandas.io import sql
import MySQLdb
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql+mysqldb://root:"+'PASSWORD'+"@localhost/NAME-OF-DATABASE")
dat_org.to_sql(name = 'TABLE-NAME',con=engine, if_exists='replace', index=False)
